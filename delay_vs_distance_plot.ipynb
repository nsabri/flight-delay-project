# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load the training dataset
df = pd.read_csv("flight_data_with_dist_and_dur.csv")
df.head()
# Out:
#            ID       DATOP     FLTID DEPSTN ARRSTN                  STD
# 0  train_id_0  2016-01-03  TU 0712     CMN    TUN  2016-01-03 10:30:00  \
# 1  train_id_1  2016-01-13  TU 0757     MXP    TUN  2016-01-13 15:05:00
# 2  train_id_2  2016-01-16  TU 0214     TUN    IST  2016-01-16 04:10:00
# 3  train_id_3  2016-01-17  TU 0480     DJE    NTE  2016-01-17 14:10:00
# 4  train_id_4  2016-01-17  TU 0338     TUN    ALG  2016-01-17 14:30:00
#
#                    STA STATUS         AC  target  flight_duration
# 0  2016-01-03 12:55:00    ATA  TU 32AIMN   260.0            145.0  \
# 1  2016-01-13 16:55:00    ATA  TU 31BIMO    20.0            110.0
# 2  2016-01-16 06:45:00    ATA  TU 32AIMN     0.0            155.0
# 3  2016-01-17 17:00:00    ATA  TU 736IOK     0.0            170.0
# 4  2016-01-17 15:50:00    ATA  TU 320IMU    22.0             80.0
#
#    flight_distance
# 0             1664
# 1              984
# 2             1670
# 3             1805
# 4              625

# %%
# Set figure size and style
plt.figure(figsize=(12, 6))
sns.set_theme(style="ticks", font_scale=1.25)

g = sns.relplot(data=df, x="flight_duration", y="target", s=35, kind="scatter", color="slategrey")
g.ax.margins(.05)
g.despine(offset=5)
g.figure.set_size_inches(12, 6)

# Set titles and labels
plt.title('Are you getting late whith time?', fontsize=24)
plt.xlabel('Flight duration [min]', fontsize=16, fontweight='bold')
plt.ylabel('Delay [min]', fontsize=16, fontweight='bold')

plt.show()

# %%
# Set figure size and style
plt.figure(figsize=(12, 6))
sns.set_theme(style="ticks", font_scale=1.25)

g = sns.relplot(data=df, x="flight_distance", y="target", s=35, kind="scatter", color="slategrey")
g.ax.margins(.05)
g.despine(offset=5)
g.figure.set_size_inches(12, 6)

# Set titles and labels
plt.title('Are you getting late with distance?', fontsize=24)
plt.xlabel('Flight distance [km]', fontsize=16, fontweight='bold')
plt.ylabel('Delay [min]', fontsize=16, fontweight='bold')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 5))
sns.boxplot(x=df["target"])
# Out:
# <Axes: xlabel='target'>

# %%
fig, ax = plt.subplots(figsize=(15, 5))
sns.boxplot(x=df["flight_duration"])
# Out:
# <Axes: xlabel='flight_duration'>

# %%
sns.histplot(x=df["flight_duration"], binwidth=10, kde=True)
# Out:
# <Axes: xlabel='flight_duration', ylabel='Count'>

# %%
sns.histplot(x=df["target"], binwidth=30, kde=True)
# Out:
# <Axes: xlabel='target', ylabel='Count'>

# %%
# Set figure size and style
plt.figure(figsize=(12, 6))
sns.set_theme(style="ticks", font_scale=1.25)

g = sns.relplot(data=df, x="flight_distance", y="flight_duration", s=35, kind="scatter", color="slategrey")
g.ax.margins(.05)
g.despine(offset=5)
g.figure.set_size_inches(12, 6)

# Set titles and labels
plt.title('Travelling takes its time.', fontsize=24)
plt.xlabel('Flight distance [km]', fontsize=16, fontweight='bold')
plt.ylabel('Flight duration [min]', fontsize=16, fontweight='bold')

plt.show()

# %%
# Set figure size and style
plt.figure(figsize=(12, 6))
sns.set_theme(style="ticks", font_scale=1.25)

g = sns.relplot(data=df, x="DATOP", y="target", s=35, kind="scatter", color="slategrey")
g.ax.margins(.05)
g.despine(offset=5)
g.figure.set_size_inches(12, 6)

# Set titles and labels
plt.title('Did you get better with time?', fontsize=24)
plt.xlabel('Flight Date', fontsize=16, fontweight='bold')
plt.ylabel('Average delay [min]', fontsize=16, fontweight='bold')
plt.xticks([])

plt.show()
